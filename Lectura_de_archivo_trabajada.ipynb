# %% [markdown]
# <a href="https://colab.research.google.com/github/elyspajaro53-afk/carpeta-sena/blob/main/Lectura_de_archivo_trabajada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CSV

# %%
import pandas as pd
# URL de ejemplo de un CSV público en GitHub (dataset 'tips' de seaborn)
csv_url = "https://raw.githubusercontent.com/elyspajaro53-afk/carpeta-sena/refs/heads/main/tips.csv"
#csv_url="https://raw.githubusercontent.com/elyspajaro53-afk/carpeta-sena/refs/heads/main/tips.csv"

# Leemos el archivo CSV directamente desde la URL
#df_csv = pd.read_csv(csv_url)
df_csv = pd.read_csv(csv_url)

# Mostramos las primeras filas para verificar
df_csv.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# TXT

# %%
# EJEMPLO 2: archivo separado por punto y coma
# Reemplaza esta URL por la de tu archivo TXT en GitHub

txt_url = "https://raw.githubusercontent.com/elyspajaro53-afk/carpeta-sena/refs/heads/main/fichero_lab_unir.txt"

df_txt = pd.read_csv(txt_url, sep=",",)
df_txt.head()
# Out:
#    Unnamed: 0 num_expediente       fecha      hora  \
# 0           0    2021S000047  01/01/2021  11:38:00
# 1           1    2021S000142  04/01/2021  11:30:00
# 2           2    2021S000142  04/01/2021  11:30:00
# 3           3    2021S000142  04/01/2021  11:30:00
# 4           4    2021S000142  04/01/2021  11:30:00
#
#                                         localizacion numero  cod_distrito  \
# 0  CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...     62            14
# 1   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 2   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 3   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 4   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
#
#               distrito tipo_accidente estado_meteorológico  ...  \
# 0            MORATALAZ          Caída            Despejado  ...
# 1  SAN BLAS-CANILLEJAS          Caída            Despejado  ...
# 2  SAN BLAS-CANILLEJAS          Caída            Despejado  ...
# 3  SAN BLAS-CANILLEJAS          Caída            Despejado  ...
# 4  SAN BLAS-CANILLEJAS          Caída            Despejado  ...
#
#         rango_edad    sexo cod_lesividad  \
# 0  De 45 a 49 años  Hombre           2.0
# 1  De 15 a 17 años  Hombre          14.0
# 2  De 18 a 20 años  Hombre          14.0
# 3  De 21 a 24 años  Hombre          14.0
# 4  De 50 a 54 años  Hombre           6.0
#
#                                       tipo_lesividad  coordenada_x_utm  \
# 0                Ingreso inferior o igual a 24 horas       446.426.917
# 1                           Sin asistencia sanitaria       448.606.811
# 2                           Sin asistencia sanitaria       448.606.811
# 3                           Sin asistencia sanitaria       448.606.811
# 4  Asistencia sanitaria inmediata en centro de sa...       448.606.811
#
#   coordenada_y_utm positiva_alcohol positiva_droga tipo_vehiculo  lesividad
# 0    4.473.586.644                N            NaN           NaN        NaN
# 1    4.476.216.426                N            NaN           NaN        NaN
# 2    4.476.216.426                N            NaN           NaN        NaN
# 3    4.476.216.426                N            NaN           NaN        NaN
# 4    4.476.216.426                N            NaN           NaN        NaN
#
# [5 rows x 22 columns]
# Warning: Total number of columns (22) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_40['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_42['cod_distrito'].plot(kind='hist', bins=20, title='cod_distrito')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_43['cod_lesividad'].plot(kind='hist', bins=20, title='cod_lesividad')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_44.groupby('num_expediente').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_45.groupby('fecha').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_46.groupby('hora').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_47.groupby('localizacion').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_48.plot(kind='scatter', x='index', y='Unnamed: 0', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_49.plot(kind='scatter', x='Unnamed: 0', y='cod_distrito', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_50.plot(kind='scatter', x='cod_distrito', y='cod_lesividad', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['cod_lesividad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_51.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('num_expediente')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='num_expediente', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('cod_lesividad')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['cod_lesividad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_52.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('fecha')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='fecha', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('cod_lesividad')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['cod_lesividad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_53.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('hora')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='hora', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('cod_lesividad')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['cod_lesividad']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_54.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('localizacion')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='localizacion', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('cod_lesividad')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_55['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_56['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_57['cod_distrito'].plot(kind='line', figsize=(8, 4), title='cod_distrito')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_58['cod_lesividad'].plot(kind='line', figsize=(8, 4), title='cod_lesividad')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['fecha'].value_counts()
#     for x_label, grp in _df_59.groupby('num_expediente')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('num_expediente')
# _ = plt.ylabel('fecha')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['hora'].value_counts()
#     for x_label, grp in _df_60.groupby('fecha')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('fecha')
# _ = plt.ylabel('hora')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['localizacion'].value_counts()
#     for x_label, grp in _df_61.groupby('hora')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('hora')
# _ = plt.ylabel('localizacion')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['numero'].value_counts()
#     for x_label, grp in _df_62.groupby('localizacion')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('localizacion')
# _ = plt.ylabel('numero')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_63['num_expediente'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_63, x='index', y='num_expediente', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_64['fecha'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_64, x='index', y='fecha', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_65['hora'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_65, x='index', y='hora', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_66['localizacion'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_66, x='index', y='localizacion', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# JSON

# %%
# URL de ejemplo de un JSON público (películas de vega-datasets)
json_url = "https://raw.githubusercontent.com/elyspajaro53-afk/carpeta-sena/refs/heads/main/peliculas.json"

# Leemos el archivo JSON
df_json = pd.read_json(json_url)

df_json.head()
# Out:
#                         Title   US Gross  Worldwide Gross  US DVD Sales  \
# 0              The Land Girls   146083.0         146083.0           NaN
# 1      First Love, Last Rites    10876.0          10876.0           NaN
# 2  I Married a Strange Person   203134.0         203134.0           NaN
# 3        Let's Talk About Sex   373615.0         373615.0           NaN
# 4                        Slam  1009819.0        1087521.0           NaN
#
#    Production Budget Release Date MPAA Rating  Running Time min Distributor  \
# 0          8000000.0  Jun 12 1998           R               NaN    Gramercy
# 1           300000.0  Aug 07 1998           R               NaN      Strand
# 2           250000.0  Aug 28 1998        None               NaN   Lionsgate
# 3           300000.0  Sep 11 1998        None               NaN   Fine Line
# 4          1000000.0  Oct 09 1998           R               NaN     Trimark
#
#                 Source Major Genre         Creative Type Director  \
# 0                 None        None                  None     None
# 1                 None       Drama                  None     None
# 2                 None      Comedy                  None     None
# 3                 None      Comedy                  None     None
# 4  Original Screenplay       Drama  Contemporary Fiction     None
#
#    Rotten Tomatoes Rating  IMDB Rating  IMDB Votes
# 0                     NaN          6.1      1071.0
# 1                     NaN          6.9       207.0
# 2                     NaN          6.8       865.0
# 3                    13.0          NaN         NaN
# 4                    62.0          3.4       165.0

# %% [markdown]
# JSON LINEA A LINEA

# %%
# Plantilla para leer un JSON línea a línea (NDJSON)
json_url = "https://raw.githubusercontent.com/elyspajaro53-afk/carpeta-sena/refs/heads/main/example_004_movies.json"

df = pd.read_json(json_url)
df.head(6)
# Out:
#                                   title  year cast  \
# 0            After Dark in Central Park  1900   []
# 1  Boarding School Girls' Pajama Parade  1900   []
# 2        Buffalo Bill's Wild West Parad  1900   []
# 3                                Caught  1900   []
# 4                  Clowns Spinning Hats  1900   []
# 5    Capture of Boer Battery by British  1900   []
#
#                          genres                                href  \
# 0                            []                                None
# 1                            []                                None
# 2                            []                                None
# 3                            []                                None
# 4                      [Silent]                Clowns_Spinning_Hats
# 5  [Short, Documentary, Silent]  Capture_of_Boer_Battery_by_British
#
#                                              extract  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Clowns Spinning Hats is a black-and-white sile...
# 5  Capture of Boer Battery by British is a black-...
#
#                                            thumbnail  thumbnail_width  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
# 5  https://upload.wikimedia.org/wikipedia/commons...            320.0
#
#    thumbnail_height
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5             240.0

# %% [markdown]
# EXCEL

# %%
# Plantilla de URL para un archivo de Excel en GitHub
#excel_url = "https://github.com/usuario/repositorio/raw/rama/ruta/archivo.xlsx"  # ERROR
import pandas as pd
excel_url = "https://raw.githubusercontent.com/elyspajaro53-afk/carpeta-sena/main/Ventas%20(Trabajo%20final).xlsx"

# Lectura de una sola hoja (por defecto la primera)
#df_excel = pd.read_excel(excel_url)
#df_excel.head()

# Lectura de una hoja específica por nombre  Hoja 1
df_excel_hoja1 = pd.read_excel(excel_url, sheet_name="Cliente")
df_excel_hoja1.head()
# Out:
#   Identificación_Clie   Nombres Apellidos     Genero     Celular Nacionalidad  \
# 0            CLIE1000     Sofía      Díaz    Femnino  3690840711   Colombiano
# 1            CLIE1001    Andrés     López  Masculino  3458297268      Chileno
# 2            CLIE1002     Laura     Pérez    Femnino  3796345771    Argentino
# 3            CLIE1003  Fernando  Martínez  Masculino  3175272825    Argentino
# 4            CLIE1004     María    Torres    Femnino  3355109790      Chileno
#
#   Estado Civil
# 0      Soltero
# 1       Casado
# 2  Unión Libre
# 3  Unión Libre
# 4      Soltero

# %%
# Lectura de una hoja específica por nombre  Hoja 2
df_excel_hoja2 = pd.read_excel(excel_url, sheet_name="Articulo")
df_excel_hoja2.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0        NaN         NaN         NaN         NaN        NaN            NaN
# 1        NaN         NaN         NaN         NaN        NaN            NaN
# 2  CódigoArt         NaN         NaN      Nombre  Proveedor  Precio Compra
# 3     ART100         NaN         NaN  Producto_0     Adidas         420496
# 4     ART101         NaN         NaN  Producto_1     Hasbro          49255
#
#          Unnamed: 6
# 0               NaN
# 1               NaN
# 2         Categoría
# 3  Electrodoméstico
# 4           Muebles

# %%
# Lectura de una hoja específica por nombre  Hoja 3
df_excel_hoja3 = pd.read_excel(excel_url, sheet_name="Vendedor")
df_excel_hoja3.head()
# Out:
#   Identificación_Vend   Nombres  Apellidos     Genero     Celular
# 0             VEND200   Bleider  Hernández  Masculino  3273198382
# 1             VEND201    Martin      Gómez  Masculino  3889697273
# 2             VEND202    Sandra      Gómez   Femenino  3644821826
# 3             VEND203  Yolaider   Martínez   Femenino  3779028607
# 4             VEND204     Pablo      Gómez  Masculino  3490105229

# %%
# Lectura de una hoja específica por nombre  Hoja 4
df_excel_hoja4 = pd.read_excel(excel_url, sheet_name="Factura")
df_excel_hoja4.head()
# Out:
#         Fecha  Todorico #Factura   Cliente Articulo Vendedor  Cantidad  \
# 0  01/02/2023       NaN  FACT563  CLIE1012   ART125  VEND207         3
# 1  02/02/2023       NaN  FACT551  CLIE1035   ART117  VEND201         5
# 2  23/02/2023       NaN  FACT507  CLIE1005   ART115  VEND202         8
# 3  11/03/2023       NaN  FACT543  CLIE1049   ART129  VEND209         1
# 4  16/03/2023       NaN  FACT561  CLIE1033   ART125  VEND209         3
#
#    Precio Venta  SuperGiros
# 0        520000         NaN
# 1        350000         NaN
# 2        300000         NaN
# 3        450000         NaN
# 4        600000         NaN

# %% [markdown]
#  Excel como diccionario de DataFrames

# %%
# Lectura de todas las hojas de un Excel (cuando tengas una URL válida)
all_sheets = pd.read_excel(excel_url, sheet_name=None)

# Recorremos las hojas y mostramos el nombre y las primeras filas
for sheet_name, df_sheet in all_sheets.items():
     print(f"Hoja: {sheet_name}")
     display(df_sheet.head())
     print("-" * 40)
# Out:
# Hoja: Cliente
#   Identificación_Clie   Nombres Apellidos     Genero     Celular Nacionalidad  \
# 0            CLIE1000     Sofía      Díaz    Femnino  3690840711   Colombiano
# 1            CLIE1001    Andrés     López  Masculino  3458297268      Chileno
# 2            CLIE1002     Laura     Pérez    Femnino  3796345771    Argentino
# 3            CLIE1003  Fernando  Martínez  Masculino  3175272825    Argentino
# 4            CLIE1004     María    Torres    Femnino  3355109790      Chileno
#
#   Estado Civil
# 0      Soltero
# 1       Casado
# 2  Unión Libre
# 3  Unión Libre
# 4      Soltero
# ----------------------------------------
# Hoja: Articulo
#   Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 0        NaN         NaN         NaN         NaN        NaN            NaN
# 1        NaN         NaN         NaN         NaN        NaN            NaN
# 2  CódigoArt         NaN         NaN      Nombre  Proveedor  Precio Compra
# 3     ART100         NaN         NaN  Producto_0     Adidas         420496
# 4     ART101         NaN         NaN  Producto_1     Hasbro          49255
#
#          Unnamed: 6
# 0               NaN
# 1               NaN
# 2         Categoría
# 3  Electrodoméstico
# 4           Muebles
# ----------------------------------------
# Hoja: Vendedor
#   Identificación_Vend   Nombres  Apellidos     Genero     Celular
# 0             VEND200   Bleider  Hernández  Masculino  3273198382
# 1             VEND201    Martin      Gómez  Masculino  3889697273
# 2             VEND202    Sandra      Gómez   Femenino  3644821826
# 3             VEND203  Yolaider   Martínez   Femenino  3779028607
# 4             VEND204     Pablo      Gómez  Masculino  3490105229
# ----------------------------------------
# Hoja: Factura
#         Fecha  Todorico #Factura   Cliente Articulo Vendedor  Cantidad  \
# 0  01/02/2023       NaN  FACT563  CLIE1012   ART125  VEND207         3
# 1  02/02/2023       NaN  FACT551  CLIE1035   ART117  VEND201         5
# 2  23/02/2023       NaN  FACT507  CLIE1005   ART115  VEND202         8
# 3  11/03/2023       NaN  FACT543  CLIE1049   ART129  VEND209         1
# 4  16/03/2023       NaN  FACT561  CLIE1033   ART125  VEND209         3
#
#    Precio Venta  SuperGiros
# 0        520000         NaN
# 1        350000         NaN
# 2        300000         NaN
# 3        450000         NaN
# 4        600000         NaN
# ----------------------------------------

# %% [markdown]
# PARQUET

# %%
# Plantilla de URL para un archivo Parquet en GitHub
import pandas as pd

# CORRECTED URL for raw Parquet file content on GitHub
parquet_url = "https://raw.githubusercontent.com/elyspajaro53-afk/carpeta-sena/main/fichero_lab_unir.parquet"
df_parquet = pd.read_parquet(parquet_url)
df_parquet.head()
# Out:
#    Unnamed: 0 num_expediente       fecha      hora  \
# 0           0    2021S000047  01/01/2021  11:38:00
# 1           1    2021S000142  04/01/2021  11:30:00
# 2           2    2021S000142  04/01/2021  11:30:00
# 3           3    2021S000142  04/01/2021  11:30:00
# 4           4    2021S000142  04/01/2021  11:30:00
#
#                                         localizacion numero  cod_distrito  \
# 0  CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...     62            14
# 1   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 2   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 3   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 4   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
#
#               distrito tipo_accidente estado_meteorológico  ...  \
# 0            MORATALAZ          Caída            Despejado  ...
# 1  SAN BLAS-CANILLEJAS          Caída            Despejado  ...
# 2  SAN BLAS-CANILLEJAS          Caída            Despejado  ...
# 3  SAN BLAS-CANILLEJAS          Caída            Despejado  ...
# 4  SAN BLAS-CANILLEJAS          Caída            Despejado  ...
#
#         rango_edad    sexo cod_lesividad  \
# 0  De 45 a 49 años  Hombre           2.0
# 1  De 15 a 17 años  Hombre          14.0
# 2  De 18 a 20 años  Hombre          14.0
# 3  De 21 a 24 años  Hombre          14.0
# 4  De 50 a 54 años  Hombre           6.0
#
#                                       tipo_lesividad  coordenada_x_utm  \
# 0                Ingreso inferior o igual a 24 horas       446.426.917
# 1                           Sin asistencia sanitaria       448.606.811
# 2                           Sin asistencia sanitaria       448.606.811
# 3                           Sin asistencia sanitaria       448.606.811
# 4  Asistencia sanitaria inmediata en centro de sa...       448.606.811
#
#   coordenada_y_utm positiva_alcohol positiva_droga tipo_vehiculo  lesividad
# 0    4.473.586.644                N            NaN          None       None
# 1    4.476.216.426                N            NaN          None       None
# 2    4.476.216.426                N            NaN          None       None
# 3    4.476.216.426                N            NaN          None       None
# 4    4.476.216.426                N            NaN          None       None
#
# [5 rows x 22 columns]
# Warning: Total number of columns (22) exceeds max_columns (20) limiting to first (20) columns.
